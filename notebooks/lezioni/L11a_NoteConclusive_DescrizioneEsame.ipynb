# %% [markdown]
# # Note Conclusive - Descrizione Esame

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Argomenti Avanzati

# %% [markdown]
# Per ognuno degli argmenti affrontati durante il corso sono possibili notevoli approfontimenti, alcuni in parte trattati nel libro di testo consigliato.

# %% [markdown]
# Oltre ad approfondimenti relativi alle tecniche trattate, esistono diversi argomenti avanzati che prevedono la conoscenza di metodi base, ad esempio:
#
# * Data Science
# * Machine Learning
# * Calcolo con GPU
# * Parallelizzazione

# %% [markdown]
# ## Linguaggi o Pacchetti Alternativi

# %% [markdown]
# Python è uno dei linguaggi più utilizzati con funzionalità e pacchetti disponibili in continua espansione ma esistono diverse piattaforme alternative, alcune particolarmente utilizzate all'interno di comunità specifiche.

# %% [markdown]
# Alcuni esempi di possibili piattaforme alternative:
#
# * ROOT  (basato su C++): https://root.cern/
#     * Utilizzabile attraverso python col pacchetto PyROOT (https://root.cern/manual/python/)
#
# * Origin: https://www.originlab.com/
#
# * MATLAB: https://it.mathworks.com/products/matlab.html
#
# * MATHEMATICA: https://www.wolfram.com/mathematica/

# %% [markdown]
# ## Esame

# %% [markdown]
# L'esame si compone di due parti:
# * La realizzazine di un progetto da consegnare in anticipo;
# * Un esame orale in cui verranno discussi il progetto e le tecniche computazionali utilizzate.

# %% [markdown]
# ### Progetto

# %% [markdown]
# Il progetto verrà assegnato dal docente anche su base di eventuali proposte degli studenti.
#
# I progetti, tendenzialmente differenziati, prevederanno la combinazione di più tecniche utilizzate durante il corso.
#
# #### GitHub
#
# Il progetto va inserito in un repository GitHub dedicato.
#
# La consegna del progetto avviene attraverso l'invio al docente, tramite e-mail, del link al repository GitHub.
#
# La consegna del progetto deve avvenire ALMENO una settimana prima della data stabilita per l'orale.
#
# #### Validazione progetto
#
# Il repository GitHub deve essre corredato da un file _README_ contenente le istruzioni necessarue per utilizzare le funzionalità sviluppate.
#
# Condizione NECESSARIA per l'accesso all'orale è che il docente, segunedo le istruzioni del file _README_,  riesca ad eseguire con successo TUTTI gli sript richiesti o a verificare TUTTE le funzionalità stabilite al momento dell'assegnazione del progetto.

# %% [markdown]
# ### Esame Orale

# %% [markdown]
# L'esame orale verterà sulla descrizione del progetto e sulla motivazione delle scelte fatte durante lo sviluppo.
#
# Le scelte fatte andranno motivate sia dal punto di vista informatico che fisico o matematico.
#
# Si richiede di preparare una breve presentazione come supporto per la descrizione del progetto (massimo 15 slide).
